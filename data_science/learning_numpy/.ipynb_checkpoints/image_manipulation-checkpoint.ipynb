# %%
import numpy as np
import imageio.v3 as iio
from scipy import ndimage

# %%
img_array = iio.imread('datasets/koala.jpg')

# %%
# (x-axis, y-axis, rgb)
img_array.shape
# Out:
# (720, 902, 3)

# %%
type(img_array)
# Out:
# numpy.ndarray

# %%
img_array
# Out:
# array([[[ 52,  62,  63],
#         [ 38,  50,  50],
#         [ 18,  32,  33],
#         ...,
#         [ 21,  38,   4],
#         [ 29,  47,   7],
#         [ 41,  60,  14]],
#
#        [[ 60,  70,  71],
#         [ 42,  52,  53],
#         [ 19,  30,  34],
#         ...,
#         [ 19,  36,   0],
#         [ 28,  46,   4],
#         [ 40,  60,  11]],
#
#        [[ 59,  67,  69],
#         [ 40,  50,  51],
#         [ 18,  29,  33],
#         ...,
#         [ 25,  43,   1],
#         [ 32,  51,   5],
#         [ 40,  60,   9]],
#
#        ...,
#
#        [[ 89,  63,  50],
#         [ 83,  59,  47],
#         [ 98,  74,  64],
#         ...,
#         [255, 253, 255],
#         [255, 253, 255],
#         [255, 253, 255]],
#
#        [[ 78,  52,  39],
#         [ 77,  50,  39],
#         [ 85,  61,  51],
#         ...,
#         [255, 253, 255],
#         [255, 253, 255],
#         [255, 253, 255]],
#
#        [[ 71,  45,  32],
#         [ 71,  44,  33],
#         [ 69,  45,  35],
#         ...,
#         [255, 253, 255],
#         [255, 253, 255],
#         [255, 253, 255]]], dtype=uint8)

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img_array)
plt.show()

# %%
# Contains all the rows starting from index 300.
# Contains all the columns starting from index 250.
# Get all the RGB value for a full-color image.
sliced_image = img_array[300:, 250:, :]

# %%
plt.imshow(sliced_image)
plt.show()

# %%
x1, x2 = np.split(img_array, 2)

# %%
plt.imshow(x1)
plt.show()

# %%
plt.imshow(x2)
plt.show()

# %%
y1, y2 = np.split(img_array, 2, axis=1)

# %%
plt.imshow(y1)
plt.show()

# %%
plt.imshow(y2)
plt.show()

# %%
plt.imshow(np.concatenate((x1, x2)))
plt.show()

# %%
plt.imshow(np.concatenate((y1, y2)))
plt.show()

# %%
plt.imshow(np.concatenate((y1, y2), axis=1))
plt.show()
