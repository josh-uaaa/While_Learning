# %%
import numpy as np

# %%
x = np.arange(10)**3
x
# Out:
# array([  0,   1,   8,  27,  64, 125, 216, 343, 512, 729])

# %%
x[3]
# Out:
# np.int64(27)

# %%
x[-4]
# Out:
# np.int64(216)

# %%
x[1:8]
# Out:
# array([  1,   8,  27,  64, 125, 216, 343])

# %%
x[3:-3]
# Out:
# array([ 27,  64, 125, 216])

# %%
x[:8]
# Out:
# array([  0,   1,   8,  27,  64, 125, 216, 343])

# %%
x[3:]
# Out:
# array([ 27,  64, 125, 216, 343, 512, 729])

# %%
x[:10:2]
# Out:
# array([  0,   8,  64, 216, 512])

# %%
x[::-1]
# Out:
# array([729, 512, 343, 216, 125,  64,  27,   8,   1,   0])

# %%
companies = np.array([['Samsung', 'Microsoft', 'IBM', 'Spotify', 'Flipkart'],
                      [1938, 1975, 1911, 2006, 2007],
                      [489000, 131000, 380000, 3000, 30000]])
companies
# Out:
# array([['Samsung', 'Microsoft', 'IBM', 'Spotify', 'Flipkart'],
#        ['1938', '1975', '1911', '2006', '2007'],
#        ['489000', '131000', '380000', '3000', '30000']], dtype='<U21')

# %%
companies[0]
# Out:
# array(['Samsung', 'Microsoft', 'IBM', 'Spotify', 'Flipkart'], dtype='<U21')

# %%
companies[:,2]
# Out:
# array(['IBM', '1911', '380000'], dtype='<U21')

# %%
companies[0, 2]
# Out:
# np.str_('IBM')

# %%
companies[0:2, 2:4]
# Out:
# array([['IBM', 'Spotify'],
#        ['1911', '2006']], dtype='<U21')

# %%
companies[:, 2:4]
# Out:
# array([['IBM', 'Spotify'],
#        ['1911', '2006'],
#        ['380000', '3000']], dtype='<U21')

# %%
companies[-1,:]
# Out:
# array(['489000', '131000', '380000', '3000', '30000'], dtype='<U21')

# %%
companies[0, ...]
# Out:
# array(['Samsung', 'Microsoft', 'IBM', 'Spotify', 'Flipkart'], dtype='<U21')

# %%
companies[..., 2]
# Out:
# array(['IBM', '1911', '380000'], dtype='<U21')
