# %%
import numpy as np
import pandas as pd

# %%
data = ['Sunday', 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday']

# %%
week = pd.Series(data)
week
# Out:
# 0       Sunday
# 1       Monday
# 2      Tuesday
# 3    Wednesday
# 4     Thursday
# 5       Friday
# 6     Saturday
# dtype: object

# %%
square_numbers = np.arange(14)**2
square_numbers
# Out:
# array([  0,   1,   4,   9,  16,  25,  36,  49,  64,  81, 100, 121, 144,
#        169])

# %%
square_series = pd.Series(square_numbers)
square_series
# Out:
# 0       0
# 1       1
# 2       4
# 3       9
# 4      16
# 5      25
# 6      36
# 7      49
# 8      64
# 9      81
# 10    100
# 11    121
# 12    144
# 13    169
# dtype: int32

# %%
employee_fields = ['F_Name', 'L_Name', 'Emp_ID', 'Dept']

# %%
employee_data = ['Susie', 'Schneider', '2258788', 'Accounting']

# %%
employee_series = pd.Series(index=employee_fields, data=employee_data)
employee_series
# Out:
# F_Name         Susie
# L_Name     Schneider
# Emp_ID       2258788
# Dept      Accounting
# dtype: object

# %%
country_capitals_dict = {'Afghanistan': 'Kabul',
                         'Australia': 'Canberra',
                         'Bangladesh': 'Dhaka',
                         'China': 'Beijing',
                         'France': 'Paris',
                         'India': 'New Delhi',
                         'Italy': 'Rome',
                         'USA': 'Washington D.C.'}

# %%
country_capitals_series = pd.Series(country_capitals_dict)
country_capitals_series
# Out:
# Afghanistan              Kabul
# Australia             Canberra
# Bangladesh               Dhaka
# China                  Beijing
# France                   Paris
# India                New Delhi
# Italy                     Rome
# USA            Washington D.C.
# dtype: object

# %%
country_capitals_series.values
# Out:
# array(['Kabul', 'Canberra', 'Dhaka', 'Beijing', 'Paris', 'New Delhi',
#        'Rome', 'Washington D.C.'], dtype=object)

# %%
type(country_capitals_series.values)
# Out:
# numpy.ndarray

# %%
country_capitals_series.index
# Out:
# Index(['Afghanistan', 'Australia', 'Bangladesh', 'China', 'France', 'India',
#        'Italy', 'USA'],
#       dtype='object')

# %%
country_capitals_series.iloc[0]
# Out:
# 'Kabul'

# %%
country_capitals_series.iloc[1:5]
# Out:
# Australia     Canberra
# Bangladesh       Dhaka
# China          Beijing
# France           Paris
# dtype: object

# %%
country_capitals_series['China']
# Out:
# 'Beijing'

# %%
country_capitals_series[['Afghanistan', 'France', 'India', 'USA']]
# Out:
# Afghanistan              Kabul
# France                   Paris
# India                New Delhi
# USA            Washington D.C.
# dtype: object
